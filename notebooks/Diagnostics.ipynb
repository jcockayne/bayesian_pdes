# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd ../experiments/
# Out:
# /Users/benorn/Coding/bayesian_pdes/experiments

# %%
ls
# Out:
# acceptance_probas.xlsx  config.py               mcmc.csv

# %%
results = pd.read_csv('mcmc.csv')

# %%
print 'Acceptance Ratio: {:.2f}%'.format(100*results.Acceptances.sum() * 1./len(results))
print 'Expected value: {:.6f}'.format(results.Delta.mean())
# Out:
# Acceptance Ratio: 37.60%
# Expected value: 0.038914

# %%
results.Delta.hist(color='gray', bins=40)
plt.axvline(0.04, c='red', linewidth=2, linestyle='--')

# %%
plt.plot(results.Delta)
plt.axhline(0.04, c='red', linestyle='--', linewidth=2)

# %%
from pandas.tools.plotting import autocorrelation_plot

# %%
autocorrelation_plot(results.Delta.values)
